# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from experiment import run_experiment, print_summary, print_volume_ratios
from scorers import *
from data_generators import generate_dgp

from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor

from table_viz import print_table_synthetic, print_table_lengthscale
from latex_tables import print_latex_synthetic, print_latex_lengthscale
from scatter_plotter import plot_contours_grid, run_and_plot

# %%
seed_paths = "results/synthetic_2d/seed_*.json"

res_table = print_table_synthetic(seed_paths)
res_table
# Out:
# <style type="text/css">
# #T_0c45b_row0_col0, #T_0c45b_row0_col3, #T_0c45b_row0_col6, #T_0c45b_row0_col9, #T_0c45b_row1_col0, #T_0c45b_row1_col3, #T_0c45b_row1_col6, #T_0c45b_row1_col9, #T_0c45b_row3_col0, #T_0c45b_row3_col3, #T_0c45b_row3_col6, #T_0c45b_row3_col9, #T_0c45b_row5_col0, #T_0c45b_row5_col3, #T_0c45b_row5_col6, #T_0c45b_row5_col9, #T_0c45b_row7_col0, #T_0c45b_row7_col3, #T_0c45b_row7_col6, #T_0c45b_row7_col9 {
#   border-left: 3px solid black;
# }
# #T_0c45b_row2_col0, #T_0c45b_row2_col3, #T_0c45b_row2_col6, #T_0c45b_row2_col9, #T_0c45b_row6_col0, #T_0c45b_row6_col3, #T_0c45b_row6_col6, #T_0c45b_row6_col9 {
#   background-color: #bbedc5;
#   border-left: 3px solid black;
# }
# #T_0c45b_row2_col1, #T_0c45b_row2_col2, #T_0c45b_row2_col4, #T_0c45b_row2_col5, #T_0c45b_row2_col7, #T_0c45b_row2_col8, #T_0c45b_row2_col10, #T_0c45b_row2_col11, #T_0c45b_row6_col1, #T_0c45b_row6_col4, #T_0c45b_row6_col7, #T_0c45b_row6_col10 {
#   background-color: #bbedc5;
#   background-color: #12b53e;
# }
# #T_0c45b_row4_col0, #T_0c45b_row4_col3, #T_0c45b_row4_col6, #T_0c45b_row4_col9 {
#   border-top: 3px solid black;
#   border-left: 3px solid black;
# }
# #T_0c45b_row4_col1, #T_0c45b_row4_col2, #T_0c45b_row4_col4, #T_0c45b_row4_col5, #T_0c45b_row4_col7, #T_0c45b_row4_col8, #T_0c45b_row4_col10, #T_0c45b_row4_col11 {
#   border-top: 3px solid black;
# }
# #T_0c45b_row5_col2, #T_0c45b_row5_col5, #T_0c45b_row5_col8, #T_0c45b_row5_col11 {
#   background-color: #12b53e;
# }
# #T_0c45b_row6_col2, #T_0c45b_row6_col5, #T_0c45b_row6_col8, #T_0c45b_row6_col11 {
#   background-color: #bbedc5;
# }
# </style>
# <table id="T_0c45b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >alpha</th>
#       <th id="T_0c45b_level0_col0" class="col_heading level0 col0" colspan="3">0.1</th>
#       <th id="T_0c45b_level0_col3" class="col_heading level0 col3" colspan="3">0.05</th>
#       <th id="T_0c45b_level0_col6" class="col_heading level0 col6" colspan="3">0.02</th>
#       <th id="T_0c45b_level0_col9" class="col_heading level0 col9" colspan="3">0.01</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_0c45b_level1_col0" class="col_heading level1 col0" >coverage</th>
#       <th id="T_0c45b_level1_col1" class="col_heading level1 col1" >volume</th>
#       <th id="T_0c45b_level1_col2" class="col_heading level1 col2" >wsc</th>
#       <th id="T_0c45b_level1_col3" class="col_heading level1 col3" >coverage</th>
#       <th id="T_0c45b_level1_col4" class="col_heading level1 col4" >volume</th>
#       <th id="T_0c45b_level1_col5" class="col_heading level1 col5" >wsc</th>
#       <th id="T_0c45b_level1_col6" class="col_heading level1 col6" >coverage</th>
#       <th id="T_0c45b_level1_col7" class="col_heading level1 col7" >volume</th>
#       <th id="T_0c45b_level1_col8" class="col_heading level1 col8" >wsc</th>
#       <th id="T_0c45b_level1_col9" class="col_heading level1 col9" >coverage</th>
#       <th id="T_0c45b_level1_col10" class="col_heading level1 col10" >volume</th>
#       <th id="T_0c45b_level1_col11" class="col_heading level1 col11" >wsc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c45b_level0_row0" class="row_heading level0 row0" rowspan="4">Linear</th>
#       <th id="T_0c45b_level1_row0" class="row_heading level1 row0" >Bonferroni</th>
#       <td id="T_0c45b_row0_col0" class="data row0 col0" >0.90016 ± 0.00381</td>
#       <td id="T_0c45b_row0_col1" class="data row0 col1" >4.13745 ± 0.03328</td>
#       <td id="T_0c45b_row0_col2" class="data row0 col2" >0.71391 ± 0.01359</td>
#       <td id="T_0c45b_row0_col3" class="data row0 col3" >0.94997 ± 0.00275</td>
#       <td id="T_0c45b_row0_col4" class="data row0 col4" >4.97647 ± 0.04020</td>
#       <td id="T_0c45b_row0_col5" class="data row0 col5" >0.85863 ± 0.01030</td>
#       <td id="T_0c45b_row0_col6" class="data row0 col6" >0.97996 ± 0.00163</td>
#       <td id="T_0c45b_row0_col7" class="data row0 col7" >5.97821 ± 0.06445</td>
#       <td id="T_0c45b_row0_col8" class="data row0 col8" >0.94382 ± 0.00557</td>
#       <td id="T_0c45b_row0_col9" class="data row0 col9" >0.99008 ± 0.00127</td>
#       <td id="T_0c45b_row0_col10" class="data row0 col10" >6.71683 ± 0.09442</td>
#       <td id="T_0c45b_row0_col11" class="data row0 col11" >0.97186 ± 0.00408</td>
#     </tr>
#     <tr>
#       <th id="T_0c45b_level1_row1" class="row_heading level1 row1" >Density</th>
#       <td id="T_0c45b_row1_col0" class="data row1 col0" >0.90005 ± 0.00363</td>
#       <td id="T_0c45b_row1_col1" class="data row1 col1" >3.34529 ± 0.02959</td>
#       <td id="T_0c45b_row1_col2" class="data row1 col2" >0.66097 ± 0.01517</td>
#       <td id="T_0c45b_row1_col3" class="data row1 col3" >0.95022 ± 0.00285</td>
#       <td id="T_0c45b_row1_col4" class="data row1 col4" >4.09317 ± 0.03996</td>
#       <td id="T_0c45b_row1_col5" class="data row1 col5" >0.83089 ± 0.01119</td>
#       <td id="T_0c45b_row1_col6" class="data row1 col6" >0.98014 ± 0.00173</td>
#       <td id="T_0c45b_row1_col7" class="data row1 col7" >4.96063 ± 0.06658</td>
#       <td id="T_0c45b_row1_col8" class="data row1 col8" >0.93530 ± 0.00670</td>
#       <td id="T_0c45b_row1_col9" class="data row1 col9" >0.99014 ± 0.00115</td>
#       <td id="T_0c45b_row1_col10" class="data row1 col10" >5.55893 ± 0.08743</td>
#       <td id="T_0c45b_row1_col11" class="data row1 col11" >0.96936 ± 0.00439</td>
#     </tr>
#     <tr>
#       <th id="T_0c45b_level1_row2" class="row_heading level1 row2" >Kernel</th>
#       <td id="T_0c45b_row2_col0" class="data row2 col0" >0.89886 ± 0.00382</td>
#       <td id="T_0c45b_row2_col1" class="data row2 col1" >2.48489 ± 0.02346</td>
#       <td id="T_0c45b_row2_col2" class="data row2 col2" >0.82092 ± 0.01042</td>
#       <td id="T_0c45b_row2_col3" class="data row2 col3" >0.94995 ± 0.00293</td>
#       <td id="T_0c45b_row2_col4" class="data row2 col4" >3.05467 ± 0.03167</td>
#       <td id="T_0c45b_row2_col5" class="data row2 col5" >0.90564 ± 0.00796</td>
#       <td id="T_0c45b_row2_col6" class="data row2 col6" >0.97974 ± 0.00169</td>
#       <td id="T_0c45b_row2_col7" class="data row2 col7" >3.80359 ± 0.04239</td>
#       <td id="T_0c45b_row2_col8" class="data row2 col8" >0.95963 ± 0.00452</td>
#       <td id="T_0c45b_row2_col9" class="data row2 col9" >0.99002 ± 0.00118</td>
#       <td id="T_0c45b_row2_col10" class="data row2 col10" >4.41304 ± 0.07076</td>
#       <td id="T_0c45b_row2_col11" class="data row2 col11" >0.97954 ± 0.00323</td>
#     </tr>
#     <tr>
#       <th id="T_0c45b_level1_row3" class="row_heading level1 row3" >Mahal</th>
#       <td id="T_0c45b_row3_col0" class="data row3 col0" >0.90001 ± 0.00394</td>
#       <td id="T_0c45b_row3_col1" class="data row3 col1" >2.82308 ± 0.02818</td>
#       <td id="T_0c45b_row3_col2" class="data row3 col2" >0.77994 ± 0.01252</td>
#       <td id="T_0c45b_row3_col3" class="data row3 col3" >0.95007 ± 0.00281</td>
#       <td id="T_0c45b_row3_col4" class="data row3 col4" >3.54716 ± 0.04695</td>
#       <td id="T_0c45b_row3_col5" class="data row3 col5" >0.85084 ± 0.01021</td>
#       <td id="T_0c45b_row3_col6" class="data row3 col6" >0.97994 ± 0.00172</td>
#       <td id="T_0c45b_row3_col7" class="data row3 col7" >4.88194 ± 0.08387</td>
#       <td id="T_0c45b_row3_col8" class="data row3 col8" >0.92729 ± 0.00743</td>
#       <td id="T_0c45b_row3_col9" class="data row3 col9" >0.99017 ± 0.00105</td>
#       <td id="T_0c45b_row3_col10" class="data row3 col10" >6.07201 ± 0

# %%
print_latex_synthetic(seed_paths)
# Out:
# \begin{table}[t]
#   \centering
#   \resizebox{\textwidth}{!}{%
#   \begin{tabular}{ll ccc ccc}
#     \toprule
#     & & \multicolumn{3}{c}{Linear} & \multicolumn{3}{c}{NN} \\
#     \cmidrule(lr){3-5} \cmidrule(lr){6-8}
#     $\alpha$ & Method & Coverage & Volume & WSC & Coverage & Volume & WSC \\
#     \midrule
#     \multirow{4}{*}{0.1} & Bonferroni  & 0.90016\tiny{$\pm$0.00381} & 4.13745\tiny{$\pm$0.03328} & 0.71391\tiny{$\pm$0.01359} & 0.90007\tiny{$\pm$0.00386} & 0.51110\tiny{$\pm$0.00833} & 0.88635\tiny{$\pm$0.00669} \\
#     & Mahal  & 0.90001\tiny{$\pm$0.00394} & 2.82308\tiny{$\pm$0.02818} & 0.77994\tiny{$\pm$0.01252} & 0.90034\tiny{$\pm$0.00362} & 0.50315\tiny{$\pm$0.00905} & 0.88902\tiny{$\pm$0.00568} \\
#     & Density  & 0.90005\tiny{$\pm$0.00363} & 3.34529\tiny{$\pm$0.02959} & 0.66097\tiny{$\pm$0.01517} & 0.89977\tiny{$\pm$0.00444} & 0.74175\tiny{$\pm$0.01487} & 0.88919\tiny{$\pm$0.00623} \\
#     & \textbf{Kernel}  & 0.89886\tiny{$\pm$0.00382} & \textbf{2.48489\tiny{$\pm$0.02346}} & 0.82092\tiny{$\pm$0.01042} & 0.90052\tiny{$\pm$0.00386} & \textbf{0.45890\tiny{$\pm$0.00774}} & 0.88533\tiny{$\pm$0.00727} \\
#     \midrule
#     \multirow{4}{*}{0.05} & Bonferroni  & 0.94997\tiny{$\pm$0.00275} & 4.97647\tiny{$\pm$0.04020} & 0.85863\tiny{$\pm$0.01030} & 0.95030\tiny{$\pm$0.00277} & 0.69037\tiny{$\pm$0.01230} & 0.94211\tiny{$\pm$0.00431} \\
#     & Mahal  & 0.95007\tiny{$\pm$0.00281} & 3.54716\tiny{$\pm$0.04695} & 0.85084\tiny{$\pm$0.01021} & 0.95036\tiny{$\pm$0.00255} & 0.71884\tiny{$\pm$0.01362} & 0.94241\tiny{$\pm$0.00384} \\
#     & Density  & 0.95022\tiny{$\pm$0.00285} & 4.09317\tiny{$\pm$0.03996} & 0.83089\tiny{$\pm$0.01119} & 0.95046\tiny{$\pm$0.00281} & 1.01563\tiny{$\pm$0.02712} & 0.94337\tiny{$\pm$0.00388} \\
#     & \textbf{Kernel}  & 0.94995\tiny{$\pm$0.00293} & \textbf{3.05467\tiny{$\pm$0.03167}} & 0.90564\tiny{$\pm$0.00796} & 0.95011\tiny{$\pm$0.00267} & \textbf{0.60802\tiny{$\pm$0.01079}} & 0.94026\tiny{$\pm$0.00456} \\
#     \midrule
#     \multirow{4}{*}{0.02} & Bonferroni  & 0.97996\tiny{$\pm$0.00163} & 5.97821\tiny{$\pm$0.06445} & 0.94382\tiny{$\pm$0.00557} & 0.98013\tiny{$\pm$0.00178} & 0.95647\tiny{$\pm$0.02194} & 0.97543\tiny{$\pm$0.00253} \\
#     & Mahal  & 0.97994\tiny{$\pm$0.00172} & 4.88194\tiny{$\pm$0.08387} & 0.92729\tiny{$\pm$0.00743} & 0.98009\tiny{$\pm$0.00170} & 1.10661\tiny{$\pm$0.03097} & 0.97541\tiny{$\pm$0.00260} \\
#     & Density  & 0.98014\tiny{$\pm$0.00173} & 4.96063\tiny{$\pm$0.06658} & 0.93530\tiny{$\pm$0.00670} & 0.98018\tiny{$\pm$0.00185} & 1.38108\tiny{$\pm$0.04531} & 0.97573\tiny{$\pm$0.00278} \\
#     & \textbf{Kernel}  & 0.97974\tiny{$\pm$0.00169} & \textbf{3.80359\tiny{$\pm$0.04239}} & 0.95963\tiny{$\pm$0.00452} & 0.98002\tiny{$\pm$0.00179} & \textbf{0.82686\tiny{$\pm$0.01830}} & 0.97490\tiny{$\pm$0.00260} \\
#     \midrule
#     \multirow{4}{*}{0.01} & Bonferroni  & 0.99008\tiny{$\pm$0.00127} & 6.71683\tiny{$\pm$0.09442} & 0.97186\tiny{$\pm$0.00408} & 0.98998\tiny{$\pm$0.00131} & 1.19619\tiny{$\pm$0.03910} & 0.98672\tiny{$\pm$0.00208} \\
#     & Mahal  & 0.99017\tiny{$\pm$0.00105} & 6.07201\tiny{$\pm$0.13758} & 0.96284\tiny{$\pm$0.00470} & 0.98999\tiny{$\pm$0.00127} & 1.47632\tiny{$\pm$0.05331} & 0.98673\tiny{$\pm$0.00178} \\
#     & Density  & 0.99014\tiny{$\pm$0.00115} & 5.55893\tiny{$\pm$0.08743} & 0.96936\tiny{$\pm$0.00439} & 0.99010\tiny{$\pm$0.00117} & 1.65518\tiny{$\pm$0.06259} & 0.98701\tiny{$\pm$0.00180} \\
#     & \textbf{Kernel}  & 0.99002\tiny{$\pm$0.00118} & \textbf{4.41304\tiny{$\pm$0.07076}} & 0.97954\tiny{$\pm$0.00323} & 0.98999\tiny{$\pm$0.00124} & \textbf{1.02031\tiny{$\pm$0.02455}} & 0.98679\tiny{$\pm$0.00180} \\
#     \bottomrule
#   \end{tabular}
#   }
#   \vspace{0.5em}
#   \caption{Results on synthetic data across 100 seeds. All values reported as mean $\pm$ std. Bold indicates best volume per model and $\alpha$.}
#   \label{tab:main_results_C}
#   \vspace{-1em}
# \end{table}

# %%
seed_paths = "results/lengthscale_sweep/seed_*.json"

seeds = print_table_lengthscale(seed_paths)
seeds
# Out:
# alpha                                    0.01                     \
# metric                               coverage             volume
# model  lengthscale method
# Linear 0.1         Density  0.98909 ± 0.00145  4.13983 ± 0.07949
#                    Kernel   0.98487 ± 0.00194  3.84754 ± 0.06354
#        0.3         Density  0.99012 ± 0.00172  4.92633 ± 0.11617
#                    Kernel   0.98985 ± 0.00157  4.21487 ± 0.08557
#        0.5         Density  0.99035 ± 0.00192  5.50337 ± 0.10867
#                    Kernel   0.98990 ± 0.00175  4.42099 ± 0.09306
#        0.8         Density  0.99099 ± 0.00186  6.48079 ± 0.13796
#                    Kernel   0.99007 ± 0.00186  4.66199 ± 0.09676
#        1.0         Density  0.99093 ± 0.00183  6.84038 ± 0.16236
#                    Kernel   0.98991 ± 0.00204  4.75424 ± 0.10536
#        2.0         Density  0.99090 ± 0.00202  7.28806 ± 0.20310
#                    Kernel   0.99028 ± 0.00186  4.95440 ± 0.11322
#        5.0         Density  0.99081 ± 0.00210  7.35608 ± 0.21110
#                    Kernel   0.99062 ± 0.00196  5.24838 ± 0.13560
# NN     0.1         Density  0.98969 ± 0.00157  1.04602 ± 0.03084
#                    Kernel   0.98829 ± 0.00146  0.92214 ± 0.03192
#        0.3         Density  0.98993 ± 0.00140  1.48702 ± 0.05129
#                    Kernel   0.98983 ± 0.00142  1.00377 ± 0.02982
#        0.5         Density  0.99000 ± 0.00140  1.59159 ± 0.05810
#                    Kernel   0.98989 ± 0.00156  1.05777 ± 0.03602
#        0.8         Density  0.99000 ± 0.00137  1.62273 ± 0.07164
#                    Kernel   0.98978 ± 0.00144  1.13500 ± 0.04229
#        1.0         Density  0.99000 ± 0.00138  1.62945 ± 0.07586
#                    Kernel   0.98993 ± 0.00148  1.20139 ± 0.04692
#        2.0         Density  0.99004 ± 0.00139  1.63769 ± 0.08294
#                    Kernel   0.98995 ± 0.00140  1.28713 ± 0.04928
#        5.0         Density  0.99007 ± 0.00137  1.63999 ± 0.08516
#                    Kernel   0.99009 ± 0.00158  1.42811 ± 0.06867
#
# alpha                                                       0.02  \
# metric                                    wsc           coverage
# model  lengthscale method
# Linear 0.1         Density  0.97790 ± 0.00495  0.97970 ± 0.00170
#                    Kernel   0.97267 ± 0.00552  0.97470 ± 0.00158
#        0.3         Density  0.97895 ± 0.00520  0.98051 ± 0.00219
#                    Kernel   0.97929 ± 0.00457  0.98010 ± 0.00199
#        0.5         Density  0.97052 ± 0.00691  0.98135 ± 0.00323
#                    Kernel   0.97871 ± 0.00471  0.98057 ± 0.00195
#        0.8         Density  0.96014 ± 0.00841  0.98157 ± 0.00322
#                    Kernel   0.97943 ± 0.00523  0.98117 ± 0.00223
#        1.0         Density  0.95786 ± 0.00875  0.98142 ± 0.00324
#                    Kernel   0.97905 ± 0.00490  0.98101 ± 0.00203
#        2.0         Density  0.95724 ± 0.00948  0.98143 ± 0.00325
#                    Kernel   0.97871 ± 0.00450  0.98121 ± 0.00226
#        5.0         Density  0.95757 ± 0.00961  0.98146 ± 0.00327
#                    Kernel   0.97686 ± 0.00520  0.98095 ± 0.00240
# NN     0.1         Density  0.98329 ± 0.00347  0.97989 ± 0.00233
#                    Kernel   0.97986 ± 0.00565  0.97816 ± 0.00292
#        0.3         Density  0.98414 ± 0.00210  0.98039 ± 0.00193
#                    Kernel   0.98276 ± 0.00419  0.97937 ± 0.00250
#        0.5         Density  0.98448 ± 0.00202  0.98018 ± 0.00205
#                    Kernel   0.98357 ± 0.00363  0.97971 ± 0.00240
#        0.8         Density  0.98448 ± 0.00194  0.98011 ± 0.00202
#                    Kernel   0.98400 ± 0.00313  0.98010 ± 0.00225
#        1.0         Density  0.98452 ± 0.00194  0.98012 ± 0.00207
#                    Kernel   0.98424 ± 0.00277  0.98021 ± 0.00226
#        2.0         Density  0.98452 ± 0.00206  0.98015 ± 0.00217
#                    Kernel   0.98414 ± 0.00239  0.98025 ± 0.00200
#        5.0         Density  0.98462 ± 0.00204  0.98019 ± 0.00217
#                    Kernel   0.98471 ± 0.00299  0.98009 ± 0.00233
#
# alpha                                                             \
# metric                                 volume                wsc
# model  lengthscale method
# Linear 0.1         Density  3.65743 ± 0.06676  0.96081 ± 0.00635
#                    Kernel   3.45636 ± 0.06150  0.95533 ± 0.00645
#        0.3         Density  4.27948 ± 0.08756  0.95948 ± 0.00613
#                    Kernel   3.67712 ± 0.07187  0.96133 ± 0.00792
#        0.5         Density  4.93295 ± 0.09635  0.94090 ± 0.01312
#                    Kernel   3.83086 ± 0.07402  0.96090 ± 0.00806
#        0.8         Density  5.99954 ± 0.11421  0.91810 ± 0.01576
#                    Kernel   4.03307 ± 0.07528  0.96157 ± 0.00729
#        1.0         Density  6.36322 ± 0.13938  0.91424 ± 0.01586
#                    Kernel   4.11646 ± 0.07803  0.96148 ± 0.00616
#        2.0         Density  6.80431 ± 0.17419  0.91400 ± 0.01592
#                    Kernel   4.31707 ± 0.08659  0.96081 ± 0.00595
#        5.0         Density  6.88021 ± 0.18977  0.91548 ± 0.01560
#                    Kernel   4.61485 ± 0.08904  0.95452 ± 0.00762
# NN     0.1         Density  0.87171 ± 0.02430  0.97105 ± 0.00434
#                    Kernel   0.78432 ± 0.02221  0.96614 ± 0.00675
#        0.3         Density  1.24713 ± 0.03970  0.97276 ± 0.00369
#                    Kernel   0.81882 ± 0.02065  0.96933 ± 0.00553
#        0.5         Density  1.35669 ± 0.04473  0.97248 ± 0.00366
#                    Kernel   0.84846 ± 0.02124  0.97033 ± 0.00451
#        0.8         Density  1.39582 ± 0.05130  0.97252 ± 0.00374
#                    Kernel   0.90393 ± 0.02528  0.97162 ± 0.00441
#        1.0         Density  1.40416 ± 0.05389  0.97238 ± 0.00365
#                    Kernel   0.95271 ± 0.02952  0.97214 ± 0.00390
#        2.0         Density  1.41468 ± 0.05860  0.97248 ± 0.00389
#                    Kernel   1.01828 ± 0.03039  0.97257 ± 0.00338
#        5.0         Density  1.41761 ± 0.05991  0.97257 ± 0.00384
#                    Kernel   1.13080 ± 0.03827  0.97324 ± 0.00358
#
# alpha                                    0.05                     \
# metric                               coverage             volume
# model  lengthscale method
# Linear 0.1         Density  0.94990 ± 0.00327  2.96526 ± 0.04963
#                    Kernel   0.94345 ± 0.00365  2.85422 ± 0.03656
#        0.3         Density  0.95109 ± 0.00407  3.43340 ± 0.06112
#                    Kernel   0.95064 ± 0.00358  2.98107 ± 0.04969
#        0.5         Density  0.95197 ± 0.00445  4.08088 ± 0.05998
#                    Kernel   0.95081 ± 0.00403  3.07326 ± 0.05210
#        0.8         Density  0.95127 ± 0.00488  5.14043 ± 0.06718
#                    Kernel   0.95046 ± 0.00412  3.20406 ± 0.05628
#        1.0         Density  0.95122 ± 0.00491  5.50945 ± 0.08870
#                    Kernel   0.95099 ± 0.00459  3.27998 ± 0.06195
#        2.0         Density  0.95145 ± 0.00475  5.92955 ± 0.13990
#                    Kernel   0.95116 ± 0.00452  3.45757 ± 0.06024
#        5.0         Density  0.95144 ± 0.00453  6.00493 ± 0.14783
#                    Kernel   0.95166 ± 0.00406  3.77140 ± 0.07772
# NN     0.1         Density  0.95015 ± 0.00399  0.65108 ± 0.01412
#                    Kernel   0.94791 ± 0.00382  0.59864 ± 0.01196
#        0.3         Density  0.95086 ± 0.00428  0.91608 ± 0.02466
#                    Kernel   0.95011 ± 0.00349  0.61330 ± 0.01168
#        0.5         Density  0.95097 ± 0.00417  1.00827 ± 0.02728
#                    Kernel   0.95041 ± 0.00314  0.62425 ± 0.01229
#        0.8         Density  0.95098 ± 0.00437  1.05129 ± 0.02940
#                    Kernel   0.95040 ± 0.00389  0.64439 ± 0.01236
#        1.0         Density  0.95107 ± 0.00436  1.06211 ± 0.02985
#                    Kernel   0.95055 ± 0.00413  0.66165 ± 0.01484
#        2.0         Density  0.95092 ± 0.00445  1.07643 ± 0.03049
#                    Kernel   0.95112 ± 0.00409  0.69110 ± 0.01666
#        5.0         Density  0.95092 ± 0.00442  1.08088 ± 0.03066
#                    Kernel   0.95115 ± 0.00387  0.76402 ± 0.02121
#
# alpha                                                       0.10  \
# metric                                    wsc           coverage
# model  lengthscale method
# Linear 0.1         Density  0.90229 ± 0.01342  0.89872 ± 0.00522
#                    Kernel   0.90400 ± 0.01245  0.89065 ± 0.00426
#        0.3         Density  0.90014 ± 0.01083  0.90129 ± 0.00527
#                    Kernel   0.90848 ± 0.01016  0.89964 ± 0.00529
#        0.5         Density  0.83886 ± 0.01876  0.90099 ± 0.00557
#                    Kernel   0.90452 ± 0.01236  0.90083 ± 0.00573
#        0.8         Density  0.78571 ± 0.02241  0.90167 ± 0.00545
#                    Kernel   0.90048 ± 0.01211  0.90185 ± 0.00561
#        1.0         Density  0.77838 ± 0.02235  0.90194 ± 0.00548
#                    Kernel   0.90152 ± 0.01184  0.90108 ± 0.00518
#        2.0         Density  0.78014 ± 0.02203  0.90123 ± 0.00566
#                    Kernel   0.90210 ± 0.01187  0.90029 ± 0.00568
#        5.0         Density  0.78548 ± 0.02030  0.90103 ± 0.00585
#                    Kernel   0.88700 ± 0.01343  0.90080 ± 0.00557
# NN     0.1         Density  0.93538 ± 0.00717  0.90019 ± 0.00543
#                    Kernel   0.92833 ± 0.00786  0.89840 ± 0.00473
#        0.3         Density  0.94057 ± 0.00664  0.90032 ± 0.00564
#                    Kernel   0.93171 ± 0.00718  0.90093 ± 0.00514
#        0.5         Density  0.94052 ± 0.00662  0.90062 ± 0.00573
#                    Kernel   0.93329 ± 0.00657  0.90115 ± 0.00560
#        0.8         Density  0.94057 ± 0.00709  0.90052 ± 0.00582
#                    Kernel   0.93495 ± 0.00617  0.90139 ± 0.00522
#        1.0         Density  0.94062 ± 0.00718  0.90070 ± 0.00568
#                    Kernel   0.93619 ± 0.00671  0.90110 ± 0.00541
#        2.0         Density  0.94043 ± 0.00719  0.90090 ± 0.00540
#                    Kernel   0.93871 ± 0.00647  0.90090 ± 0.00517
#        5.0         Density  0.94048 ± 0.00720  0.90103 ± 0.00539
#                    Kernel   0.94062 ± 0.00597  0.90037 ± 0.00519
#
# alpha
# metric                                 volume                wsc
# model  lengthscale method
# Linear 0.1         Density  2.40666 ± 0.03372  0.80686 ± 0.01878
#                    Kernel   2.32507 ± 0.02593  0.81424 ± 0.01750
#        0.3         Density  2.74557 ± 0.04104  0.81057 ± 0.01539
#                    Kernel   2.42346 ± 0.03463  0.82324 ± 0.01776
#        0.5         Density  3.33558 ± 0.04632  0.66976 ± 0.02183
#                    Kernel   2.50061 ± 0.03817  0.81824 ± 0.01708
#        0.8         Density  4.20237 ± 0.06372  0.58948 ± 0.02272
#                    Kernel   2.60484 ± 0.04225  0.81433 ± 0.01681
#        1.0         Density  4.53486 ± 0.07131  0.58110 ± 0.02373
#                    Kernel   2.65114 ± 0.04094  0.81214 ± 0.01574
#        2.0         Density  4.96452 ± 0.08779  0.58943 ± 0.02418
#                    Kernel   2.79988 ± 0.03948  0.80586 ± 0.01531
#        5.0         Density  5.07019 ± 0.09638  0.59986 ± 0.02441
#                    Kernel   3.04592 ± 0.04627  0.77005 ± 0.02118
# NN     0.1         Density  0.48773 ± 0.00952  0.87529 ± 0.01077
#                    Kernel   0.45945 ± 0.00831  0.87014 ± 0.01040
#        0.3         Density  0.66943 ± 0.01504  0.88200 ± 0.01067
#                    Kernel   0.46516 ± 0.00848  0.87229 ± 0.01051
#        0.5         Density  0.74302 ± 0.01815  0.88233 ± 0.01053
#                    Kernel   0.46954 ± 0.00888  0.87310 ± 0.01210
#        0.8         Density  0.77771 ± 0.01979  0.88210 ± 0.01096
#                    Kernel   0.47791 ± 0.00917  0.87367 ± 0.01127
#        1.0         Density  0.78709 ± 0.01986  0.88205 ± 0.01071
#                    Kernel   0.48445 ± 0.01015  0.87395 ± 0.01198
#        2.0         Density  0.80086 ± 0.01970  0.88248 ± 0.01072
#                    Kernel   0.49489 ± 0.01089  0.87605 ± 0.01227
#        5.0         Density  0.80511 ± 0.01986  0.88257 ± 0.01086
#                    Kernel   0.53423 ± 0.01079  0.88171 ± 0.01133

# %%
print_latex_lengthscale(seed_paths)
# Out:
# \begin{sidewaystable}[p]
#   \centering
#   \resizebox{\textwidth}{!}{%
#   \begin{tabular}{lll ccc ccc ccc ccc}
#     \toprule
#     & & & \multicolumn{3}{c}{$\alpha=0.10$} & \multicolumn{3}{c}{$\alpha=0.05$} & \multicolumn{3}{c}{$\alpha=0.02$} & \multicolumn{3}{c}{$\alpha=0.01$} \\
#     \cmidrule(lr){4-6} \cmidrule(lr){7-9} \cmidrule(lr){10-12} \cmidrule(lr){13-15}
#     Model & $\ell$ & Method & Coverage & Volume & WSC & Coverage & Volume & WSC & Coverage & Volume & WSC & Coverage & Volume & WSC \\
#     \midrule
#     \multirow{14}{*}{Linear} & \multirow{2}{*}{0.10} & Density & 0.89872\tiny{$\pm$0.00522} & 2.40666\tiny{$\pm$0.03372} & 0.80686\tiny{$\pm$0.01878} & 0.94990\tiny{$\pm$0.00327} & 2.96526\tiny{$\pm$0.04963} & 0.90229\tiny{$\pm$0.01342} & 0.97970\tiny{$\pm$0.00170} & 3.65743\tiny{$\pm$0.06676} & 0.96081\tiny{$\pm$0.00635} & 0.98909\tiny{$\pm$0.00145} & 4.13983\tiny{$\pm$0.07949} & 0.97790\tiny{$\pm$0.00495} \\[4pt]
#     &  & \textbf{Kernel} & 0.89065\tiny{$\pm$0.00426} & \textbf{2.32507\tiny{$\pm$0.02593}} & 0.81424\tiny{$\pm$0.01750} & 0.94345\tiny{$\pm$0.00365} & \textbf{2.85422\tiny{$\pm$0.03656}} & 0.90400\tiny{$\pm$0.01245} & 0.97470\tiny{$\pm$0.00158} & \textbf{3.45636\tiny{$\pm$0.06150}} & 0.95533\tiny{$\pm$0.00645} & 0.98487\tiny{$\pm$0.00194} & \textbf{3.84754\tiny{$\pm$0.06354}} & 0.97267\tiny{$\pm$0.00552} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{0.30} & Density & 0.90129\tiny{$\pm$0.00527} & 2.74557\tiny{$\pm$0.04104} & 0.81057\tiny{$\pm$0.01539} & 0.95109\tiny{$\pm$0.00407} & 3.43340\tiny{$\pm$0.06112} & 0.90014\tiny{$\pm$0.01083} & 0.98051\tiny{$\pm$0.00219} & 4.27948\tiny{$\pm$0.08756} & 0.95948\tiny{$\pm$0.00613} & 0.99012\tiny{$\pm$0.00172} & 4.92633\tiny{$\pm$0.11617} & 0.97895\tiny{$\pm$0.00520} \\[4pt]
#     &  & \textbf{Kernel} & 0.89964\tiny{$\pm$0.00529} & \textbf{2.42346\tiny{$\pm$0.03463}} & 0.82324\tiny{$\pm$0.01776} & 0.95064\tiny{$\pm$0.00358} & \textbf{2.98107\tiny{$\pm$0.04969}} & 0.90848\tiny{$\pm$0.01016} & 0.98010\tiny{$\pm$0.00199} & \textbf{3.67712\tiny{$\pm$0.07187}} & 0.96133\tiny{$\pm$0.00792} & 0.98985\tiny{$\pm$0.00157} & \textbf{4.21487\tiny{$\pm$0.08557}} & 0.97929\tiny{$\pm$0.00457} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{0.50} & Density & 0.90099\tiny{$\pm$0.00557} & 3.33558\tiny{$\pm$0.04632} & 0.66976\tiny{$\pm$0.02183} & 0.95197\tiny{$\pm$0.00445} & 4.08088\tiny{$\pm$0.05998} & 0.83886\tiny{$\pm$0.01876} & 0.98135\tiny{$\pm$0.00323} & 4.93295\tiny{$\pm$0.09635} & 0.94090\tiny{$\pm$0.01312} & 0.99035\tiny{$\pm$0.00192} & 5.50337\tiny{$\pm$0.10867} & 0.97052\tiny{$\pm$0.00691} \\[4pt]
#     &  & \textbf{Kernel} & 0.90083\tiny{$\pm$0.00573} & \textbf{2.50061\tiny{$\pm$0.03817}} & 0.81824\tiny{$\pm$0.01708} & 0.95081\tiny{$\pm$0.00403} & \textbf{3.07326\tiny{$\pm$0.05210}} & 0.90452\tiny{$\pm$0.01236} & 0.98057\tiny{$\pm$0.00195} & \textbf{3.83086\tiny{$\pm$0.07402}} & 0.96090\tiny{$\pm$0.00806} & 0.98990\tiny{$\pm$0.00175} & \textbf{4.42099\tiny{$\pm$0.09306}} & 0.97871\tiny{$\pm$0.00471} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{0.80} & Density & 0.90167\tiny{$\pm$0.00545} & 4.20237\tiny{$\pm$0.06372} & 0.58948\tiny{$\pm$0.02272} & 0.95127\tiny{$\pm$0.00488} & 5.14043\tiny{$\pm$0.06718} & 0.78571\tiny{$\pm$0.02241} & 0.98157\tiny{$\pm$0.00322} & 5.99954\tiny{$\pm$0.11421} & 0.91810\tiny{$\pm$0.01576} & 0.99099\tiny{$\pm$0.00186} & 6.48079\tiny{$\pm$0.13796} & 0.96014\tiny{$\pm$0.00841} \\[4pt]
#     &  & \textbf{Kernel} & 0.90185\tiny{$\pm$0.00561} & \textbf{2.60484\tiny{$\pm$0.04225}} & 0.81433\tiny{$\pm$0.01681} & 0.95046\tiny{$\pm$0.00412} & \textbf{3.20406\tiny{$\pm$0.05628}} & 0.90048\tiny{$\pm$0.01211} & 0.98117\tiny{$\pm$0.00223} & \textbf{4.03307\tiny{$\pm$0.07528}} & 0.96157\tiny{$\pm$0.00729} & 0.99007\tiny{$\pm$0.00186} & \textbf{4.66199\tiny{$\pm$0.09676}} & 0.97943\tiny{$\pm$0.00523} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{1.00} & Density & 0.90194\tiny{$\pm$0.00548} & 4.53486\tiny{$\pm$0.07131} & 0.58110\tiny{$\pm$0.02373} & 0.95122\tiny{$\pm$0.00491} & 5.50945\tiny{$\pm$0.08870} & 0.77838\tiny{$\pm$0.02235} & 0.98142\tiny{$\pm$0.00324} & 6.36322\tiny{$\pm$0.13938} & 0.91424\tiny{$\pm$0.01586} & 0.99093\tiny{$\pm$0.00183} & 6.84038\tiny{$\pm$0.16236} & 0.95786\tiny{$\pm$0.00875} \\[4pt]
#     &  & \textbf{Kernel} & 0.90108\tiny{$\pm$0.00518} & \textbf{2.65114\tiny{$\pm$0.04094}} & 0.81214\tiny{$\pm$0.01574} & 0.95099\tiny{$\pm$0.00459} & \textbf{3.27998\tiny{$\pm$0.06195}} & 0.90152\tiny{$\pm$0.01184} & 0.98101\tiny{$\pm$0.00203} & \textbf{4.11646\tiny{$\pm$0.07803}} & 0.96148\tiny{$\pm$0.00616} & 0.98991\tiny{$\pm$0.00204} & \textbf{4.75424\tiny{$\pm$0.10536}} & 0.97905\tiny{$\pm$0.00490} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{2.00} & Density & 0.90123\tiny{$\pm$0.00566} & 4.96452\tiny{$\pm$0.08779} & 0.58943\tiny{$\pm$0.02418} & 0.95145\tiny{$\pm$0.00475} & 5.92955\tiny{$\pm$0.13990} & 0.78014\tiny{$\pm$0.02203} & 0.98143\tiny{$\pm$0.00325} & 6.80431\tiny{$\pm$0.17419} & 0.91400\tiny{$\pm$0.01592} & 0.99090\tiny{$\pm$0.00202} & 7.28806\tiny{$\pm$0.20310} & 0.95724\tiny{$\pm$0.00948} \\[4pt]
#     &  & \textbf{Kernel} & 0.90029\tiny{$\pm$0.00568} & \textbf{2.79988\tiny{$\pm$0.03948}} & 0.80586\tiny{$\pm$0.01531} & 0.95116\tiny{$\pm$0.00452} & \textbf{3.45757\tiny{$\pm$0.06024}} & 0.90210\tiny{$\pm$0.01187} & 0.98121\tiny{$\pm$0.00226} & \textbf{4.31707\tiny{$\pm$0.08659}} & 0.96081\tiny{$\pm$0.00595} & 0.99028\tiny{$\pm$0.00186} & \textbf{4.95440\tiny{$\pm$0.11322}} & 0.97871\tiny{$\pm$0.00450} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{5.00} & Density & 0.90103\tiny{$\pm$0.00585} & 5.07019\tiny{$\pm$0.09638} & 0.59986\tiny{$\pm$0.02441} & 0.95144\tiny{$\pm$0.00453} & 6.00493\tiny{$\pm$0.14783} & 0.78548\tiny{$\pm$0.02030} & 0.98146\tiny{$\pm$0.00327} & 6.88021\tiny{$\pm$0.18977} & 0.91548\tiny{$\pm$0.01560} & 0.99081\tiny{$\pm$0.00210} & 7.35608\tiny{$\pm$0.21110} & 0.95757\tiny{$\pm$0.00961} \\[4pt]
#     &  & \textbf{Kernel} & 0.90080\tiny{$\pm$0.00557} & \textbf{3.04592\tiny{$\pm$0.04627}} & 0.77005\tiny{$\pm$0.02118} & 0.95166\tiny{$\pm$0.00406} & \textbf{3.77140\tiny{$\pm$0.07772}} & 0.88700\tiny{$\pm$0.01343} & 0.98095\tiny{$\pm$0.00240} & \textbf{4.61485\tiny{$\pm$0.08904}} & 0.95452\tiny{$\pm$0.00762} & 0.99062\tiny{$\pm$0.00196} & \textbf{5.24838\tiny{$\pm$0.13560}} & 0.97686\tiny{$\pm$0.00520} \\[4pt]
#     \midrule
#     \midrule
#     \multirow{14}{*}{NN} & \multirow{2}{*}{0.10} & Density & 0.90019\tiny{$\pm$0.00543} & 0.48773\tiny{$\pm$0.00952} & 0.87529\tiny{$\pm$0.01077} & 0.95015\tiny{$\pm$0.00399} & 0.65108\tiny{$\pm$0.01412} & 0.93538\tiny{$\pm$0.00717} & 0.97989\tiny{$\pm$0.00233} & 0.87171\tiny{$\pm$0.02430} & 0.97105\tiny{$\pm$0.00434} & 0.98969\tiny{$\pm$0.00157} & 1.04602\tiny{$\pm$0.03084} & 0.98329\tiny{$\pm$0.00347} \\[4pt]
#     &  & \textbf{Kernel} & 0.89840\tiny{$\pm$0.00473} & \textbf{0.45945\tiny{$\pm$0.00831}} & 0.87014\tiny{$\pm$0.01040} & 0.94791\tiny{$\pm$0.00382} & \textbf{0.59864\tiny{$\pm$0.01196}} & 0.92833\tiny{$\pm$0.00786} & 0.97816\tiny{$\pm$0.00292} & \textbf{0.78432\tiny{$\pm$0.02221}} & 0.96614\tiny{$\pm$0.00675} & 0.98829\tiny{$\pm$0.00146} & \textbf{0.92214\tiny{$\pm$0.03192}} & 0.97986\tiny{$\pm$0.00565} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{0.30} & Density & 0.90032\tiny{$\pm$0.00564} & 0.66943\tiny{$\pm$0.01504} & 0.88200\tiny{$\pm$0.01067} & 0.95086\tiny{$\pm$0.00428} & 0.91608\tiny{$\pm$0.02466} & 0.94057\tiny{$\pm$0.00664} & 0.98039\tiny{$\pm$0.00193} & 1.24713\tiny{$\pm$0.03970} & 0.97276\tiny{$\pm$0.00369} & 0.98993\tiny{$\pm$0.00140} & 1.48702\tiny{$\pm$0.05129} & 0.98414\tiny{$\pm$0.00210} \\[4pt]
#     &  & \textbf{Kernel} & 0.90093\tiny{$\pm$0.00514} & \textbf{0.46516\tiny{$\pm$0.00848}} & 0.87229\tiny{$\pm$0.01051} & 0.95011\tiny{$\pm$0.00349} & \textbf{0.61330\tiny{$\pm$0.01168}} & 0.93171\tiny{$\pm$0.00718} & 0.97937\tiny{$\pm$0.00250} & \textbf{0.81882\tiny{$\pm$0.02065}} & 0.96933\tiny{$\pm$0.00553} & 0.98983\tiny{$\pm$0.00142} & \textbf{1.00377\tiny{$\pm$0.02982}} & 0.98276\tiny{$\pm$0.00419} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{0.50} & Density & 0.90062\tiny{$\pm$0.00573} & 0.74302\tiny{$\pm$0.01815} & 0.88233\tiny{$\pm$0.01053} & 0.95097\tiny{$\pm$0.00417} & 1.00827\tiny{$\pm$0.02728} & 0.94052\tiny{$\pm$0.00662} & 0.98018\tiny{$\pm$0.00205} & 1.35669\tiny{$\pm$0.04473} & 0.97248\tiny{$\pm$0.00366} & 0.99000\tiny{$\pm$0.00140} & 1.59159\tiny{$\pm$0.05810} & 0.98448\tiny{$\pm$0.00202} \\[4pt]
#     &  & \textbf{Kernel} & 0.90115\tiny{$\pm$0.00560} & \textbf{0.46954\tiny{$\pm$0.00888}} & 0.87310\tiny{$\pm$0.01210} & 0.95041\tiny{$\pm$0.00314} & \textbf{0.62425\tiny{$\pm$0.01229}} & 0.93329\tiny{$\pm$0.00657} & 0.97971\tiny{$\pm$0.00240} & \textbf{0.84846\tiny{$\pm$0.02124}} & 0.97033\tiny{$\pm$0.00451} & 0.98989\tiny{$\pm$0.00156} & \textbf{1.05777\tiny{$\pm$0.03602}} & 0.98357\tiny{$\pm$0.00363} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{0.80} & Density & 0.90052\tiny{$\pm$0.00582} & 0.77771\tiny{$\pm$0.01979} & 0.88210\tiny{$\pm$0.01096} & 0.95098\tiny{$\pm$0.00437} & 1.05129\tiny{$\pm$0.02940} & 0.94057\tiny{$\pm$0.00709} & 0.98011\tiny{$\pm$0.00202} & 1.39582\tiny{$\pm$0.05130} & 0.97252\tiny{$\pm$0.00374} & 0.99000\tiny{$\pm$0.00137} & 1.62273\tiny{$\pm$0.07164} & 0.98448\tiny{$\pm$0.00194} \\[4pt]
#     &  & \textbf{Kernel} & 0.90139\tiny{$\pm$0.00522} & \textbf{0.47791\tiny{$\pm$0.00917}} & 0.87367\tiny{$\pm$0.01127} & 0.95040\tiny{$\pm$0.00389} & \textbf{0.64439\tiny{$\pm$0.01236}} & 0.93495\tiny{$\pm$0.00617} & 0.98010\tiny{$\pm$0.00225} & \textbf{0.90393\tiny{$\pm$0.02528}} & 0.97162\tiny{$\pm$0.00441} & 0.98978\tiny{$\pm$0.00144} & \textbf{1.13500\tiny{$\pm$0.04229}} & 0.98400\tiny{$\pm$0.00313} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{1.00} & Density & 0.90070\tiny{$\pm$0.00568} & 0.78709\tiny{$\pm$0.01986} & 0.88205\tiny{$\pm$0.01071} & 0.95107\tiny{$\pm$0.00436} & 1.06211\tiny{$\pm$0.02985} & 0.94062\tiny{$\pm$0.00718} & 0.98012\tiny{$\pm$0.00207} & 1.40416\tiny{$\pm$0.05389} & 0.97238\tiny{$\pm$0.00365} & 0.99000\tiny{$\pm$0.00138} & 1.62945\tiny{$\pm$0.07586} & 0.98452\tiny{$\pm$0.00194} \\[4pt]
#     &  & \textbf{Kernel} & 0.90110\tiny{$\pm$0.00541} & \textbf{0.48445\tiny{$\pm$0.01015}} & 0.87395\tiny{$\pm$0.01198} & 0.95055\tiny{$\pm$0.00413} & \textbf{0.66165\tiny{$\pm$0.01484}} & 0.93619\tiny{$\pm$0.00671} & 0.98021\tiny{$\pm$0.00226} & \textbf{0.95271\tiny{$\pm$0.02952}} & 0.97214\tiny{$\pm$0.00390} & 0.98993\tiny{$\pm$0.00148} & \textbf{1.20139\tiny{$\pm$0.04692}} & 0.98424\tiny{$\pm$0.00277} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{2.00} & Density & 0.90090\tiny{$\pm$0.00540} & 0.80086\tiny{$\pm$0.01970} & 0.88248\tiny{$\pm$0.01072} & 0.95092\tiny{$\pm$0.00445} & 1.07643\tiny{$\pm$0.03049} & 0.94043\tiny{$\pm$0.00719} & 0.98015\tiny{$\pm$0.00217} & 1.41468\tiny{$\pm$0.05860} & 0.97248\tiny{$\pm$0.00389} & 0.99004\tiny{$\pm$0.00139} & 1.63769\tiny{$\pm$0.08294} & 0.98452\tiny{$\pm$0.00206} \\[4pt]
#     &  & \textbf{Kernel} & 0.90090\tiny{$\pm$0.00517} & \textbf{0.49489\tiny{$\pm$0.01089}} & 0.87605\tiny{$\pm$0.01227} & 0.95112\tiny{$\pm$0.00409} & \textbf{0.69110\tiny{$\pm$0.01666}} & 0.93871\tiny{$\pm$0.00647} & 0.98025\tiny{$\pm$0.00200} & \textbf{1.01828\tiny{$\pm$0.03039}} & 0.97257\tiny{$\pm$0.00338} & 0.98995\tiny{$\pm$0.00140} & \textbf{1.28713\tiny{$\pm$0.04928}} & 0.98414\tiny{$\pm$0.00239} \\[4pt]
#     \cmidrule(lr){2-15}
#     & \multirow{2}{*}{5.00} & Density & 0.90103\tiny{$\pm$0.00539} & 0.80511\tiny{$\pm$0.01986} & 0.88257\tiny{$\pm$0.01086} & 0.95092\tiny{$\pm$0.00442} & 1.08088\tiny{$\pm$0.03066} & 0.94048\tiny{$\pm$0.00720} & 0.98019\tiny{$\pm$0.00217} & 1.41761\tiny{$\pm$0.05991} & 0.97257\tiny{$\pm$0.00384} & 0.99007\tiny{$\pm$0.00137} & 1.63999\tiny{$\pm$0.08516} & 0.98462\tiny{$\pm$0.00204} \\[4pt]
#     &  & \textbf{Kernel} & 0.90037\tiny{$\pm$0.00519} & \textbf{0.53423\tiny{$\pm$0.01079}} & 0.88171\tiny{$\pm$0.01133} & 0.95115\tiny{$\pm$0.00387} & \textbf{0.76402\tiny{$\pm$0.02121}} & 0.94062\tiny{$\pm$0.00597} & 0.98009\tiny{$\pm$0.00233} & \textbf{1.13080\tiny{$\pm$0.03827}} & 0.97324\tiny{$\pm$0.00358} & 0.99009\tiny{$\pm$0.00158} & \textbf{1.42811\tiny{$\pm$0.06867}} & 0.98471\tiny{$\pm$0.00299} \\[4pt]
#     \bottomrule
#   \end{tabular}
#   }
#   \vspace{0.5em}
#   \caption{Density vs Kernel ablation across lengthscale values on 2D synthetic data (21 seeds). Bold indicates lowest volume.}
#   \label{tab:main_results_lengthscale}
# \end{sidewaystable}

# %%
import matplotlib.pyplot as plt

scorer_factories = {
    'Mahal':      lambda: MahalanobisScorer(),
    'Kernel':     lambda: KernelScorer(auto_parameters=False, lengthscale=0.5),
}

models = {
    'Linear': LinearRegression(),
}

fig, out = run_and_plot(generate_dgp, models, scorer_factories,
                        alphas=[0.1, 0.05, 0.02, 0.01], xlim=(-2.2, 2), ylim=(-1.8, 2),
                        seed=24, n=16_000,
                        figsize=(6, 3.33333333))

# plt.savefig('scatter_linear_l05.pdf', dpi=600, bbox_inches='tight')
# Out:
# /Users/louismeyer/Desktop/PhD Research/Conformal Prediction/mvcp/synthetic_experiments/scatter_plotter.py:149: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
scorer_factories = {
    'Mahal':      lambda: MahalanobisScorer(),
    'Kernel':     lambda: KernelScorer(auto_parameters=False, lengthscale=0.5),
}

models = {
    'NN': MLPRegressor(hidden_layer_sizes=(64, 64), max_iter=1000),
}

fig, out = run_and_plot(generate_dgp, models, scorer_factories,
                        alphas=[0.1, 0.05, 0.02, 0.01], xlim=(-1.1, 1.1), ylim=(-1, 1),
                        seed=24, n=16_000,
                        figsize=(6, 4.666666666666667), show_ylabel=False)

# plt.savefig('scatter_NN5_noylabel_l05.pdf', dpi=600, bbox_inches='tight')
# Out:
# /Users/louismeyer/Desktop/PhD Research/Conformal Prediction/mvcp/synthetic_experiments/scatter_plotter.py:149: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
